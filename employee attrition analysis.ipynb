# %%
#import necessary libraries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib as mlt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load data
df=pd.read_excel('D:/Data Science/DATASCIENCE PROJECTS/case study/casestudy.xlsx',sheet_name='Existing employees')
Y=pd.read_excel('D:/Data Science/DATASCIENCE PROJECTS/case study/casestudy.xlsx',sheet_name='Employees who have left')
Y
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0      14999                0.37             0.52               2
# 1      14998                0.11             0.96               6
# 2      14997                0.37             0.53               2
# 3      14996                0.37             0.48               2
# 4      14995                0.40             0.57               2
# ...      ...                 ...              ...             ...
# 3566       5                0.10             0.89               2
# 3567       4                0.10             0.89               5
# 3568       3                0.10             0.89               7
# 3569       2                0.10             0.89               5
# 3570       1                0.10             0.89               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      158                   3              0
# ...

# %%
### Check for missing values

# %%
Y.isnull().sum()
# Out:
# Emp ID                      0
# satisfaction_level          0
# last_evaluation             0
# number_project              0
# average_montly_hours        0
# time_spend_company          0
# Work_accident               0
# promotion_last_5years       0
# dept                        0
# salary                      0
# Unnamed: 10              3571
# dtype: int64

# %% [markdown]
# Since both existing employee and non-existing employee data are in different sheets.My approach is to merge both sheets.to identify employees i give a status 1 for existing employee and for non-existing employee i give status as 0.

# %%
df['status']=1

# %%
df.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0   14211                0.50             0.73               4
# 1   14210                0.33             0.65               3
# 2   14209                0.85             0.54               3
# 3   14208                0.74             0.95               5
# 4   14207                0.90             0.55               3
#
#    average_montly_hours  average_montly_hours.1  Work_accident  \
# 0                   180                       3              0
# 1                   172                      10              0
# 2                   185                      10              0
# 3                   266                      10              0
# 4                   259                      10              1
#
#    promotion_last_5years        dept salary  status
# 0                      0          IT    low       1
# 1                      1   marketing   high       1
# ...

# %%
Y.fillna(0,inplace=True)

# %%
Y.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0   14999                0.37             0.52               2
# 1   14998                0.11             0.96               6
# 2   14997                0.37             0.53               2
# 3   14996                0.37             0.48               2
# 4   14995                0.40             0.57               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   158                   3              0
# 1                   280                   4              0
# 2                   143                   3              0
# 3                   160                   3              0
# 4                   151                   3              0
#
#    promotion_last_5years     dept salary  Unnamed: 10
# 0                      0  support    low          0.0
# 1                      0  support    low          0.0
# 2                      0  support    low          0.0
# ...

# %%
Y.drop('Unnamed: 10',axis=1,inplace=True)

# %% [markdown]
# 'Unnamed: 10' column has almost null values.I am dropping that colummn.

# %%
Y.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0   14999                0.37             0.52               2
# 1   14998                0.11             0.96               6
# 2   14997                0.37             0.53               2
# 3   14996                0.37             0.48               2
# 4   14995                0.40             0.57               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   158                   3              0
# 1                   280                   4              0
# 2                   143                   3              0
# 3                   160                   3              0
# 4                   151                   3              0
#
#    promotion_last_5years     dept salary
# 0                      0  support    low
# 1                      0  support    low
# 2                      0  support    low
# 3                      0  support    low
# ...

# %%
Y['status']=0

# %%
Y.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0   14999                0.37             0.52               2
# 1   14998                0.11             0.96               6
# 2   14997                0.37             0.53               2
# 3   14996                0.37             0.48               2
# 4   14995                0.40             0.57               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   158                   3              0
# 1                   280                   4              0
# 2                   143                   3              0
# 3                   160                   3              0
# 4                   151                   3              0
#
#    promotion_last_5years     dept salary  status
# 0                      0  support    low       0
# 1                      0  support    low       0
# 2                      0  support    low       0
# ...

# %%
df.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0   14211                0.50             0.73               4
# 1   14210                0.33             0.65               3
# 2   14209                0.85             0.54               3
# 3   14208                0.74             0.95               5
# 4   14207                0.90             0.55               3
#
#    average_montly_hours  average_montly_hours.1  Work_accident  \
# 0                   180                       3              0
# 1                   172                      10              0
# 2                   185                      10              0
# 3                   266                      10              0
# 4                   259                      10              1
#
#    promotion_last_5years        dept salary  status
# 0                      0          IT    low       1
# 1                      1   marketing   high       1
# ...

# %%
#combining both data
tdf4=df.append(Y,sort=True)

# %%
tdf4
# Out:
#       Emp ID  Work_accident  average_montly_hours  average_montly_hours.1  \
# 0      14211              0                   180                     3.0
# 1      14210              0                   172                    10.0
# 2      14209              0                   185                    10.0
# 3      14208              0                   266                    10.0
# 4      14207              1                   259                    10.0
# ...      ...            ...                   ...                     ...
# 3566       5              0                   159                     NaN
# 3567       4              0                   223                     NaN
# 3568       3              0                   272                     NaN
# 3569       2              0                   262                     NaN
# 3570       1              0                   157                     NaN
#
#             dept  last_evaluation  number_project  promotion_last_5years  \
# ...

# %%
miss=tdf4.isnull().sum()
miss
# Out:
# Emp ID                        0
# Work_accident                 0
# average_montly_hours          0
# average_montly_hours.1     3571
# dept                          0
# last_evaluation               0
# number_project                0
# promotion_last_5years         0
# salary                        0
# satisfaction_level            0
# status                        0
# time_spend_company        11428
# dtype: int64

# %% [markdown]
# solving the miss match occured during merging

# %%
tdf4.rename(columns={'average_montly_hours.1':'time_spend'},inplace=True)
tdf4.fillna(0,inplace=True)
#tdf4['time_spend']=tdf4['time_spend']+tdf4['time_spend_company']
#tdf4.drop('time_spend_company',axis=1,inplace=True)

# %%
tdf4.head()
# Out:
#    Emp ID  Work_accident  average_montly_hours  time_spend        dept  \
# 0   14211              0                   180         3.0          IT
# 1   14210              0                   172        10.0   marketing
# 2   14209              0                   185        10.0  management
# 3   14208              0                   266        10.0  management
# 4   14207              1                   259        10.0  management
#
#    last_evaluation  number_project  promotion_last_5years salary  \
# 0             0.73               4                      0    low
# 1             0.65               3                      1   high
# 2             0.54               3                      1   high
# 3             0.95               5                      1   high
# 4             0.55               3                      1   high
#
#    satisfaction_level  status
# 0                0.50       1
# 1                0.33       1
# 2                0.85       1
# ...

# %%
cor=tdf4.corr()
cor['status'].sort_values(ascending=False)
# Out:
# status                   1.000000
# satisfaction_level       0.411462
# Work_accident            0.154622
# Emp ID                   0.129047
# promotion_last_5years    0.061788
# number_project          -0.023787
# last_evaluation         -0.032597
# average_montly_hours    -0.071287
# time_spend              -0.144822
# Name: status, dtype: float64

# %%
tdf4['status'].value_counts()
#3571 employee has left the company 23.8%
# Out:
# 1    11428
# 0     3571
# Name: status, dtype: int64

# %%
tdf4.groupby('status').mean()
# Out:
#              Emp ID  Work_accident  average_montly_hours  time_spend  \
# status
# 0       6500.439653       0.047326            207.419210    3.876505
# 1       7812.340742       0.175009            199.060203    3.380032
#
#         last_evaluation  number_project  promotion_last_5years  \
# status
# 0              0.728549        3.855503               0.005321
# 1              0.715473        3.786664               0.026251
#
#         satisfaction_level
# status
# 0                 0.422708
# 1                 0.666810

# %%
tdf4.groupby('dept').mean()
# Out:
#                   Emp ID  Work_accident  average_montly_hours  time_spend  \
# dept
# IT           7656.845966       0.133659            202.215974    3.468623
# RandD        6778.346887       0.170267            200.800508    3.367217
# accounting   7256.035202       0.125163            201.162973    3.522816
# hr           7036.889039       0.120433            198.684709    3.355886
# management   9439.363492       0.163492            201.249206    4.303175
# marketing    7751.684149       0.160839            199.385781    3.569930
# product_mng  8096.417960       0.146341            199.965632    3.475610
# sales        7676.873430       0.141787            200.911353    3.534058
# support      7212.809780       0.154778            200.758188    3.393001
# technical    7072.437132       0.140074            202.497426    3.411397
#
#              last_evaluation  number_project  promotion_last_5years  \
# dept
# IT                  0.717302        3.816626               0.002445
# ...

# %%
tdf4.groupby('salary').mean()
# Out:
#              Emp ID  Work_accident  average_montly_hours  time_spend  \
# salary
# high    8788.155116       0.158416            200.040429    3.690594
# low     6951.103600       0.136886            201.543801    3.464069
# medium  7946.198144       0.151756            200.619450    3.503479
#
#         last_evaluation  number_project  promotion_last_5years  \
# salary
# high           0.705767        3.772277               0.059406
# low            0.722374        3.806219               0.008773
# medium         0.716297        3.805169               0.029655
#
#         satisfaction_level    status
# salary
# high              0.640932  0.952970
# low               0.584112  0.663656
# medium            0.633786  0.849735

# %% [markdown]
# ### Data Visualization

# %%
pd.crosstab(tdf4['dept'],tdf4['status']).plot(kind='bar')
plt.title('Department wise split')
plt.ylabel('frequency')
plt.xlabel('Deaprtments')
# Out:
# Text(0.5, 0, 'Deaprtments')

# %%
pd.crosstab(tdf4.salary,tdf4.status).plot(kind='bar')

# %%
num_bins=10
tdf4.hist(bins=num_bins,figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000010249F70240>,
# ...
#       dtype=object)

# %%
#getting object column names to convert it into numerical column
def catcolumns(df):
    return [cname for cname in df.columns if df[cname].dtypes=='object' ]

catcolumns(tdf4)
# Out:
# ['dept', 'salary']

# %%
def toperformencoding(df,columns_to_encode):
    return pd.get_dummies(df,columns=columns_to_encode)
cat_cols=catcolumns(tdf4)
tdf6=toperformencoding(tdf4,cat_cols)

# %%
tdf6
# Out:
#       Emp ID  Work_accident  average_montly_hours  time_spend  \
# 0      14211              0                   180         3.0
# 1      14210              0                   172        10.0
# 2      14209              0                   185        10.0
# 3      14208              0                   266        10.0
# 4      14207              1                   259        10.0
# ...      ...            ...                   ...         ...
# 3566       5              0                   159         3.0
# 3567       4              0                   223         5.0
# 3568       3              0                   272         4.0
# 3569       2              0                   262         6.0
# 3570       1              0                   157         3.0
#
#       last_evaluation  number_project  promotion_last_5years  \
# 0                0.73               4                      0
# 1                0.65               3                      1
# ...

# %%
hr=tdf6.columns.values.tolist()
y ='status'
x=[cname for cname in hr if cname not in y]

# %%
x
# Out:
# ['Work_accident',
#  'average_montly_hours',
#  'time_spend',
#  'last_evaluation',
#  'number_project',
#  'promotion_last_5years',
#  'satisfaction_level',
#  'dept_IT',
#  'dept_RandD',
#  'dept_accounting',
#  'dept_hr',
#  'dept_management',
#  'dept_marketing',
#  'dept_product_mng',
#  'dept_sales',
#  'dept_support',
#  'dept_technical',
#  'salary_high',
#  'salary_low',
#  'salary_medium']

# %%
tdf6.drop('Emp ID',axis=1,inplace=True)

# %% [markdown]
# ### Feature Selection
# The Recursive Feature Elimination (RFE)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

#Recursive Feature Elimination (RFE)
model = LogisticRegression()

rfe = RFE(model, 10)
rfe = rfe.fit(tdf6[x],tdf6[y])
print(rfe.support_)
print(rfe.ranking_)
# Out:
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
cols=['Work_accident',
 'time_spend',
 'last_evaluation',
 'number_project',
 'satisfaction_level',
 'dept_sales',
 'salary_high',
 'salary_low',
 'salary_medium']
x=tdf6[cols]
y=tdf6['status']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size= 0.3,random_state=0)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
rf=RandomForestClassifier()
rf.fit(xtrain,ytrain)
pred=rf.predict(xtest)
print(confusion_matrix(ytest,pred))
print(classification_report(ytest,pred))
#print(pred)
# Out:
# [[1015   56]
#  [  30 3399]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      1071
#            1       0.98      0.99      0.99      3429
#
#     accuracy                           0.98      4500
#    macro avg       0.98      0.97      0.97      4500
# weighted avg       0.98      0.98      0.98      4500
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold= model_selection.KFold(n_splits=10,random_state=7)
modelCV=RandomForestClassifier()
scoring='accuracy'
results = model_selection.cross_val_score(modelCV, xtrain, ytrain, cv=kfold, scoring=scoring)
# Out:
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
print(results.mean())
# Out:
# 1.0

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
svc = SVC()
svc.fit(xtrain, ytrain)
pred=svc.predict(xtest)
print(confusion_matrix(ytest,pred))
print(classification_report(ytest,pred))
#For SVM
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold = model_selection.KFold(n_splits=10, random_state=7)
modelCV = SVC()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, xtrain, ytrain, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy for SVM Classifier: %.3f" % (results.mean()))
# Out:
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [[ 961  110]
#  [ 104 3325]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      1071
#            1       0.97      0.97      0.97      3429
#
#     accuracy                           0.95      4500
#    macro avg       0.94      0.93      0.93      4500
# weighted avg       0.95      0.95      0.95      4500
# C:\Users\Roshan\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
feature_labels = np.array(['satisfaction_level', 'last_evaluation', 'time_spend_company', 'Work_accident', 'promotion_last_5years', 
      'department_RandD', 'department_hr', 'department_management', 'salary_high', 'salary_low'])
importance = rf.feature_importances_
feature_indexes_by_importance = importance.argsort()
for index in feature_indexes_by_importance:
    print('{}-{:.2f}%'.format(feature_labels[index], (importance[index] *100.0)))
# Out:
# department_hr-0.32%
# department_RandD-0.60%
# satisfaction_level-0.68%
# salary_high-0.98%
# department_management-1.13%
# time_spend_company-16.02%
# Work_accident-17.58%
# last_evaluation-18.87%
# promotion_last_5years-43.82%
